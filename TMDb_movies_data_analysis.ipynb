# %% [markdown]
# # Project: Investigate a Dataset - TMDB Movies
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# ### Dataset Description
#
# > This dataset contains information about 10,000 movies collected from `TMDb` Database including user ratings, budget for each movie and revenue.
#
# > Below is the list of columns names in our dataset and their significance
# <Ul>
#     <li>`id` - This is a unique identifier for each movie </li>
#     <li>`popularity` - A numeric quantity specifying the movie popularity </li>
#     <li>`budget` - The cost in which the movie was made </li>
#     <li>`revenue` - The worldwide revenue generated from the movie </li>
#     <li>`original_title` - The title of the movie before translation or adaptaion </li>
#     <li>`cast` - The name of lead and supporting actors </li><br>
#     <li>`homepage` - A link to the homepage of the movie </li><br>
#     <li>`director` - The directors of each movie </li><br>
#     <li>`tagline` - The movie's tagline </li><br>
#     <li>`overview` - A brief description of the movie</li><br>
#     <li>`runtime` - The running time of the movie in minutes </li><br>
#     <li>`genres` - The genre of the movies; Action, Drama,Adventure etc..</li><br>
#     <li>`Production_companies` - The production house of the movie </li><br>
#     <li>`release_date` - The date the movie was released </li><br>
#     <li>`vote_count` - The count of votes the movie received </li><br>
#     <li>`vote_average` - Average rating the movie received</li><br>
#     <li>`release_year` - The year the movie was released </li>
# </Ul>
#
#
#
#
#
#
#
# ### Question(s) for Analysis
# > This dataset will be analysed to answer the follwing the following questions;
#      1. What year did TMDb Movies made the highest profit?
#      2. Which TMDb movie has the highest profit expressed as a percentage of its budget?
#      3. What is the correlation between the attributes of our TMDb movies dataset?
#
# ### Objective of Analysis
# > The objective of our analysis are;
#     1. To identify the year TMDb movies made the highest profit
#     2. To determine the movie that has the highest percentage, when profit is expressed as a percentage of its budget.
#     3. To ascertain the correlation between different attributes of TMDb dataset.
#
# > Before we proceed in analysing our data, we need to import certain python libraries such as Numpy, pandas, Matplotlib and seaborn which we would need to read, clean, organise and visualize our data for proper understanding.
#
# > importing python libraries below

# %%
# importing libraries to use
# we are going to make use of aliases for this libraries for easy callout such as np for numpy, pd for pandas etc 
import numpy as np   
import pandas as pd

#visualisation
import matplotlib.pyplot as plt 

#visualisation
import seaborn as sns 
# %matplotlib inline

#setting the backgroud color for our charts
sns.set_style('darkgrid')

# %%
# Upgrade pandas to use dataframe.explode() function. 
# !pip install --upgrade pandas==0.25.0
# Out:
# Collecting pandas==0.25.0
#   Downloading https://files.pythonhosted.org/packages/1d/9a/7eb9952f4b4d73fbd75ad1d5d6112f407e695957444cb695cbb3cdab918a/pandas-0.25.0-cp36-cp36m-manylinux1_x86_64.whl (10.5MB)
#     100% |████████████████████████████████| 10.5MB 3.3MB/s eta 0:00:01  5% |█▉                              | 604kB 20.2MB/s eta 0:00:01    29% |█████████▎                      | 3.0MB 26.9MB/s eta 0:00:01    54% |█████████████████▋              | 5.7MB 28.1MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /opt/conda/lib/python3.6/site-packages (from pandas==0.25.0) (2.6.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas==0.25.0) (2017.3)
# Collecting numpy>=1.13.3 (from pandas==0.25.0)
#   Downloading https://files.pythonhosted.org/packages/45/b2/6c7545bb7a38754d63048c7696804a0d947328125d81bf12beaa692c3ae3/numpy-1.19.5-cp36-cp36m-manylinux1_x86_64.whl (13.4MB)
#     100% |████████████████████████████████| 13.4MB 2.4MB/s eta 0:00:01  2% |▊                               | 286kB 20.8MB/s eta 0:00:01    21% |██████▉                         | 2.8MB 22.7MB/s eta 0:00:01    30% |█████████▋                      | 4.0MB 26.8MB/s eta 0:00:01    39% |████████████▉                   | 5.4MB 28.0MB/s eta 0:00:01    59% |███████████████████             | 7.9MB 24.8MB/s eta 0:00:01    87% |████████████████████████████    | 11.7MB 25.8MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: six>=1.5 in /opt/conda/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas==0.25.0) (1.11.0)
# tensorflow 1.3.0 requires tensorflow-tensorboard<0.2.0,>=0.1.0, which is not installed.
# Installing collected packages: numpy, pandas
#   Found existing installation: numpy 1.12.1
#     Uninstalling numpy-1.12.1:
#       Successfully uninstalled numpy-1.12.1
#   Found existing installation: pandas 0.23.3
#     Uninstalling pandas-0.23.3:
#       Successfully uninstalled pandas-0.23.3
# Successfully installed numpy-1.19.5 pandas-0.25.0

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
#
#
# ### General Properties
#
# > Let's read our dataset to have a clear view of what it looks and understand its content.

# %%
# reding our data stored in csv format
df = pd.read_csv('tmdb-movies.csv')

# display the first five rows of our data
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline      ...       \
# 0              The park is open.      ...
# 1             What a Lovely Day.      ...
# 2     One Choice Can Destroy You      ...
# 3  Every generation has a story.      ...
# 4            Vengeance Hits Home      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %% [markdown]
# Above is the first five rows of our data.

# %% [markdown]
# We are going to view the shape of our data using the shape function to know the number of columns and rows contained in our dataset.

# %%
# view the shape of our dataset
df.shape
# Out:
# (10866, 21)

# %%
# for clear understanding of the values, am using print to indicate the row value and the column value
print('The number of rows are:', df.shape[0],'.', 'The number of columns are:', df.shape[1])
# Out:
# The number of rows are: 10866 . The number of columns are: 21

# %% [markdown]
# To further understand our data, we are going to use the info funtion to get more information about the structure of our dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
# id                      10866 non-null int64
# imdb_id                 10856 non-null object
# popularity              10866 non-null float64
# budget                  10866 non-null int64
# revenue                 10866 non-null int64
# original_title          10866 non-null object
# cast                    10790 non-null object
# homepage                2936 non-null object
# director                10822 non-null object
# tagline                 8042 non-null object
# keywords                9373 non-null object
# overview                10862 non-null object
# runtime                 10866 non-null int64
# genres                  10843 non-null object
# production_companies    9836 non-null object
# release_date            10866 non-null object
# vote_count              10866 non-null int64
# vote_average            10866 non-null float64
# release_year            10866 non-null int64
# budget_adj              10866 non-null float64
# revenue_adj             10866 non-null float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %% [markdown]
# From the above infomation we have five float datatype, six intergers and eleven objects. We can see as well that there are columns with null /NaN values which we would handle when cleaning our data in the next step below

# %% [markdown]
# ### Data Cleaning
#
# > We need to clean our data to ultimately increase the overall productivity of our data and allow the highest quality information in our decision making.
#
# > Things we would do to clean and get our data ready are:
#     1. Remove null values / missing values.
#     2. Remove irrelevant duplicates

# %% [markdown]
# First we need to check for null values in our dataset

# %%
#checking for number of null values in our dataset
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# We can see that there are several columns with null values. We will be droping all this null values in the next step below

# %%
# Droping all NaN and Null values in our dataset and checking if there are NaN values after dropping
df.dropna(inplace=True)

#checking if there is still null values
df.isnull().sum()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# homepage                0
# director                0
# tagline                 0
# keywords                0
# overview                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# dtype: int64

# %% [markdown]
# Result above shows there are no null values in our dataset anymore.

# %% [markdown]
#  We would proceed to check for duplicated rows in our dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates in the dataset.

# %%
#Rechecking the shape of the data
df.shape
# Out:
# (1992, 21)

# %% [markdown]
# Our rows has further reduced to 1992 because of the null values that were dropped

# %% [markdown]
# ##### Now that our data is clean we would proceed to answer our proposed questions
# Befor we proceed,based on our research questions not all columns will be needed for this analysis. We will be dropping all columns we don't need for this analysis in the next step.

# %%
#droping all irrelevant columns
df.drop(columns={'imdb_id','cast','tagline','keywords','homepage','budget_adj','revenue_adj'}, axis=1, inplace=True)

# %% [markdown]
# Let's see if the columns were actually dropped

# %%
#checking the first five rows of our data
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#            director                                           overview  \
# 0   Colin Trevorrow  Twenty-two years after the events of Jurassic ...
# 1     George Miller  An apocalyptic story set in the furthest reach...
# 2  Robert Schwentke  Beatrice Prior must confront her inner demons ...
# 3       J.J. Abrams  Thirty years after defeating the Galactic Empi...
# 4         James Wan  Deckard Shaw seeks revenge against Dominic Tor...
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# 1      120  Action|Adventure|Science Fiction|Thriller
# 2      119         Adventure|Science Fiction|Thriller
# 3      136   Action|Adventure|Science Fiction|Fantasy
# 4      137                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15        5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15        2947
#
#    vote_average  release_year
# 0           6.5          2015
# 1           7.1          2015
# 2           6.3          2015
# 3           7.5          2015
# 4           7.3          2015

# %%
#Lets view our data information to recheck if there are still errors
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1992 entries, 0 to 10819
# Data columns (total 14 columns):
# id                      1992 non-null int64
# popularity              1992 non-null float64
# budget                  1992 non-null int64
# revenue                 1992 non-null int64
# original_title          1992 non-null object
# director                1992 non-null object
# overview                1992 non-null object
# runtime                 1992 non-null int64
# genres                  1992 non-null object
# production_companies    1992 non-null object
# release_date            1992 non-null object
# vote_count              1992 non-null int64
# vote_average            1992 non-null float64
# release_year            1992 non-null int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 233.4+ KB

# %% [markdown]
# There is need to convert release_date datatype to datetime

# %%
df.release_date = pd.to_datetime(df.release_date)

# %%
#check if release_date has been converted to datetime datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1992 entries, 0 to 10819
# Data columns (total 14 columns):
# id                      1992 non-null int64
# popularity              1992 non-null float64
# budget                  1992 non-null int64
# revenue                 1992 non-null int64
# original_title          1992 non-null object
# director                1992 non-null object
# overview                1992 non-null object
# runtime                 1992 non-null int64
# genres                  1992 non-null object
# production_companies    1992 non-null object
# release_date            1992 non-null datetime64[ns]
# vote_count              1992 non-null int64
# vote_average            1992 non-null float64
# release_year            1992 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(5)
# memory usage: 233.4+ KB

# %% [markdown]
# Let's review the statistics of our dataset to check if there are any abnormality

# %%
df.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    1992.000000  1992.000000  1.992000e+03  1.992000e+03  1992.000000
# mean    71652.152108     1.316763  3.454924e+07  1.152153e+08   106.040161
# std     92355.883915     1.873563  5.061878e+07  2.202887e+08    29.234592
# min        11.000000     0.000620  0.000000e+00  0.000000e+00     0.000000
# 25%      9699.000000     0.384079  0.000000e+00  0.000000e+00    92.000000
# 50%     35112.500000     0.774223  1.500000e+07  2.578782e+07   102.000000
# 75%     83573.000000     1.538639  4.800000e+07  1.278787e+08   116.000000
# max    414419.000000    32.985763  4.250000e+08  2.781506e+09   705.000000
#
#         vote_count  vote_average  release_year
# count  1992.000000   1992.000000   1992.000000
# mean    643.616968      6.178614   2007.796687
# std    1092.355998      0.881955      7.549224
# min      10.000000      2.100000   1961.000000
# 25%      51.000000      5.600000   2006.000000
# 50%     210.000000      6.200000   2010.000000
# 75%     688.250000      6.800000   2012.000000
# max    9767.000000      8.300000   2015.000000

# %% [markdown]
# From our statistics above we can see that minimum value and 25% of budget and revenue are 0, runtime has the minimum of 0 as well which in real time context is not logical. We will proceed to fix this error in the next step

# %%
#cleaning and correcting the invalid data
# we assigned the 0 values to min_ero varible 
min_ero = df.query('budget == 0 or revenue == 0 or runtime ==0')
min_ero
# below id the rows with the zero (0) values which we need to drop
# Out:
#            id  popularity    budget    revenue  \
# 30     280996    3.927333         0   29355203
# 67     334074    2.331636  20000000          0
# 75     308369    2.141506         0          0
# 88     301875    1.959765         0    2000000
# 95     258509    1.841779         0  233755553
# 132    263109    1.253580         0   59700000
# 139    193687    1.161812         0     118483
# 143    378373    1.128081         0          0
# 148    353326    1.046518         0   11472454
# 159    251516    0.953046    630019          0
# 172    225728    0.874641         0   13192457
# 173    326425    0.872149         0      16775
# 174    342474    0.861179         0          0
# 181    322456    0.821443         0          0
# 187    334538    0.792471         0          0
# 195    331781    0.738404         0    8413144
# 197    312831    0.719407         0          0
# 201    332340    0.701370         0          0
# 212     86835    0.654335         0          0
# 214    309242    0.649628         0          0
# 215    332502    0.644786         0          0
# 237    278236    0.547827         0          0
# 239    326215    0.542568   6000000          0
# 241    318256    0.532239         0          0
# 245    309299    0.526642         0          0
# 255    336313    0.497265         0     157768
# 261    289716    0.474788         0          0
# 269    302429    0.465707         0   13603453
# 272    323373    0.454151         0          0
# 285    318922    0.438409         0          0
# ...       ...         ...       ...        ...
# 8465    11238    1.841080         0          0
# 8651     3065    0.117864         0          0
# 8733    19457    0.558581         0          0
# 8768      876    0.381729  20000000          0
# 8803    41275    0.251747         0          0
# 8852    17908    0.378034   7000000          0
# 8870    21355    0.084290  57000000          0
# 8876    21991    0.059043         0          0
# 9039     9945    0.626850  20000000          0
# 9081    16146    0.399489    650000          0
# 9286    18111    0.190250   2000000          0
# 9421     4539    0.206000         0          0
# 9539    34311    0.254965         0          0
# 9586    26355    0.076958         0   17514553
# 9631    13247    0.500666         0          0
# 9647    12476    0.099960         0          0
# 9692    22500    0.186551         0          0
# 9708    59558    0.005529         0          0
# 9763     1410    0.837644     60000          0
# 10012     530    0.519773         0          0
# 10078   12651    0.747549  23000000          0
# 10190   17814    0.374631    150000          0
# 10213   40440    0.126140         0          0
# 10238     531    0.996113         0          0
# 10328   31578    0.238862         0          0
# 10372   13063    0.181665    125000          0
# 10567   20537    0.227370         0          0
# 10657    5722    0.374514         0          0
# 10817   13963    0.064029         0     321952
# 10819   16214    0.044675         0   78000000
#
#                                           original_title  \
# 30                                            Mr. Holmes
# 67                                              Survivor
# 75                        Me and Earl and the Dying Girl
# 88                                                Equals
# 95                Alvin and the Chipmunks: The Road Chip
# 132                                Shaun the Sheep Movie
# 139                                      Z for Zachariah
# 143                                 Brothers of the Wind
# 148                            The Man Who Knew Infinity
# 159                                            Kung Fury
# 172                                              Macbeth
# 173                                           Extraction
# 174                                      Jenny's Wedding
# 181    LEGO DC Comics Super Heroes: Justice League vs...
# 187                                      Into the Forest
# 195                                                  Amy
# 197                                           The Hallow
# 201                                               Man Up
# 212                                       Knight of Cups
# 214                                    Mississippi Grind
# 215                                             400 Days
# 237                                                  X+Y
# 239                               Ooops! Noah is Gone...
# 241                                     Hot Girls Wanted
# 245                                         Experimenter
# 255                                          Hell & Back
# 261                              The World Made Straight
# 269                                        Strange Magic
# 272                                            Deathgasm
# 285                                    Kill Your Friends
# ...                                                  ...
# 8465                     Aladdin and the King of Thieves
# 8651             Mystery Science Theater 3000: The Movie
# 8733                                           The Yards
# 8768                                Frank Herbert's Dune
# 8803                                              Python
# 8852                                         My Dog Skip
# 8870                               All the Pretty Horses
# 8876                                      State and Main
# 9039                                            Vampires
# 9081                               Phantasm IV: Oblivion
# 9286                                Bride of Re-Animator
# 9421        Hearts of Darkness: A Filmmaker's Apocalypse
# 9539                  Sleepaway Camp II: Unhappy Campers
# 9586                                           For Keeps
# 9631                           A Muppet Family Christmas
# 9647                                          The Hidden
# 9692                                            Gandahar
# 9708                                    Miami Connection
# 9763                                           Dark Star
# 10012                                    A Grand Day Out
# 10078                                      Memphis Belle
# 10190                             Assault on Precinct 13
# 10213                          The Song Remains the Same
# 10238                                 The Wrong Trousers
# 10328                                          Body Bags
# 10372                              Cannibal! The Musical
# 10567                                         Caravaggio
# 10657                     Beyond the Valley of the Dolls
# 10817                                     The Last Waltz
# 10819                                             Hooper
#
#                                            director  \
# 30                                      Bill Condon
# 67                                   James McTeigue
# 75                              Alfonso Gomez-Rejon
# 88                                    Drake Doremus
# 95                                      Walt Becker
# 132                    Mark Burton|Richard Starzack
# 139                                     Craig Zobel
# 143                    Gerado Olivares|Otmar Penker
# 148                                      Matt Brown
# 159                                  David Sandberg
# 172                                   Justin Kurzel
# 173                                Steven C. Miller
# 174                             Mary Agnes Donoghue
# 181                                  Brandon Vietti
# 187                                 Patricia Rozema
# 195                                    Asif Kapadia
# 197                                     Corin Hardy
# 201                                      Ben Palmer
# 212                                 Terrence Malick
# 214                           Ryan Fleck|Anna Boden
# 215                                   Matt Osterman
# 237                                 Morgan Matthews
# 239                      Toby Genkel|Sean McCormack
# 241                         Jill Bauer|Ronna Gradus
# 245                               Michael Almereyda
# 255                          Tom Gianas|Ross Shuman
# 261                                    David Burris
# 269                                   Gary Rydstrom
# 272                                Jason Lei Howden
# 285                                     Owen Harris
# ...                                             ...
# 8465                                     Tad Stones
# 8651                                     Jim Mallon
# 8733                                     James Gray
# 8768                                  John Harrison
# 8803                               Richard Clabaugh
# 8852                                    Jay Russell
# 8870                             Billy Bob Thornton
# 8876                                    David Mamet
# 9039                                 John Carpenter
# 9081                                 Don Coscarelli
# 9286                                    Brian Yuzna
# 9421   Eleanor Coppola|Fax Bahr|George Hickenlooper
# 9539                             Michael A. Simpson
# 9586                               John G. Avildsen
# 9631                         Peter Harris|Eric Till
# 9647                                   Jack Sholder
# 9692                                   RenÃ© Laloux
# 9708                         Y.K. Kim|Woo-sang Park
# 9763                                 John Carpenter
# 10012                                     Nick Park
# 10078                           Michael Caton-Jones
# 10190                                John Carpenter
# 10213                      Peter Clifton|Joe Massot
# 10238                                     Nick Park
# 10328       John Carpenter|Tobe Hooper|Larry Sulkis
# 10372                                   Trey Parker
# 10567                                  Derek Jarman
# 10657                                    Russ Meyer
# 10817                               Martin Scorsese
# 10819                                   Hal Needham
#
#                                                 overview  runtime  \
# 30     The story is set in 1947, following a long-ret...      103
# 67     A Foreign Service Officer in London tries to p...       96
# 75     Greg is coasting through senior year of high s...      105
# 88     A futuristic love story set in a world where e...      101
# 95     Through a series of misunderstandings, Alvin, ...       92
# 132    When Shaun decides to take the day off and hav...       85
# 139    In the wake of a nuclear war, a young woman su...       97
# 143    The way of the eagle is to raise two chicks. T...       98
# 148    Growing up poor in Madras, India, Srinivasa Ra...      108
# 159    During an unfortunate series of events, a frie...       31
# 172    Feature film adaptation of Shakespeare's Scott...      113
# 173    A former CIA operative is kidnapped by a group...       83
# 174    Jenny Farrell is getting married. But how will...       94
# 181    Supermanâ€™s clone, Bizarro, has become an emb...       48
# 187    In the not too distant future, two young women...      101
# 195    A documentary on the life of Amy Winehouse, th...      128
# 197    A family who moved into a remote mill house in...       97
# 201    A 34 year old single woman, Nancy, hung-over a...       88
# 212    Once there was a young prince whose father, th...      118
# 214    Gerry is a talented but down-on-his-luck gambl...      108
# 215    4 would be astronauts spend 400 days in a land...       91
# 237    A socially awkward teenage math prodigy finds ...      111
# 239    It's the end of the world. A flood is coming. ...       85
# 241    A first-ever look at the realities of the prof...       84
# 245    Yale University, 1961. Stanley Milgram designs...       97
# 255    Two best friends set out to rescue their pal a...       86
# 261    In a rural Appalachian community haunted by th...      119
# 269    A love potion works its devious charms on fair...       99
# 272    Two teenage boys unwittingly summon an ancient...       86
# 285    In the late 1990s, a drug-addled nihilist reso...      100
# ...                                                  ...      ...
# 8465   Legendary secrets are revealed as Aladdin and ...       81
# 8651   The mad and evil scientist, Dr. Clayton Forres...       73
# 8733   In the rail yards of Queens, contractors repai...      115
# 8768   A three part mini-series based on Frank Herber...      292
# 8803   Sleepy New Haven California is a small town wi...       99
# 8852   A shy boy is unable to make friends in Yazoo C...       95
# 8870   The year is 1949. A young Texan named John Gra...      117
# 8876   A Hollywood Film unit invades a small Vermont ...      102
# 9039   The church enlists a team of vampire-hunters t...      108
# 9081   Taking off immediately where the last one ende...       90
# 9286   Herbert West once again revives the dead. This...       96
# 9421   A chronicle of the production problems â€” inc...       96
# 9539   Angela Baker, a psychotic transsexual, escapes...       80
# 9586   Darcy, editor at her highschool paper, and her...       98
# 9631   In this one-hour Christmas special, Fozzie Bea...       48
# 9647   An alien is on the run in America. To get his ...       96
# 9692   RenÃ© Laloux, director of Fantastic Planet [La...       83
# 9708   In a world where ninjas dream of being rock st...       86
# 9763   A low-budget, sci-fi satire that focuses on a ...       83
# 10012  Wallace and Gromit have run out of cheese and ...       23
# 10078  The "Memphis Belle" is a World War II bomber, ...      107
# 10190  The lone inhabitants of an abandoned police st...       91
# 10213  The best of Led Zeppelin's legendary 1973 appe...      137
# 10238  Gromit finds himself being pushed out of his r...       30
# 10328  Three tales are told, each one increasingly te...       94
# 10372  Heading through Colorado Territory in search o...       97
# 10567  As influential Italian artist Caravaggio dies ...       93
# 10657  A hip and happenin' all girl rock group head t...      109
# 10817  Martin Scorsese's rockumentary intertwines foo...      117
# 10819  Burt Reynolds plays a legendary stunt man know...      107
#
#                                                   genres  \
# 30                                         Mystery|Drama
# 67                                 Crime|Thriller|Action
# 75                                          Comedy|Drama
# 88                         Drama|Romance|Science Fiction
# 95                     Adventure|Animation|Comedy|Family
# 132                    Family|Animation|Comedy|Adventure
# 139                       Drama|Science Fiction|Thriller
# 143                               Adventure|Drama|Family
# 148                                                Drama
# 159                Action|Comedy|Science Fiction|Fantasy
# 172                                    History|Drama|War
# 173                                      Action|Thriller
# 174                                         Comedy|Drama
# 181                    Action|Adventure|Animation|Family
# 187                                Drama|Science Fiction
# 195                                    Documentary|Music
# 197                                       Fantasy|Horror
# 201                                       Romance|Comedy
# 212                                        Romance|Drama
# 214                                                Drama
# 215                     Mystery|Science Fiction|Thriller
# 237                                                Drama
# 239                           Animation|Adventure|Comedy
# 241                                          Documentary
# 245                                        History|Drama
# 255                             Fantasy|Comedy|Animation
# 261                                                Drama
# 269                       Music|Animation|Family|Fantasy
# 272                                        Comedy|Horror
# 285                                Thriller|Comedy|Crime
# ...                                                  ...
# 8465                          Adventure|Animation|Family
# 8651                              Comedy|Science Fiction
# 8733                         Drama|Action|Thriller|Crime
# 8768            Action|Adventure|Fantasy|Science Fiction
# 8803              Thriller|Comedy|Horror|Science Fiction
# 8852                                 Comedy|Drama|Family
# 8870                               Drama|Romance|Western
# 8876                                        Comedy|Drama
# 9039                Action|Drama|Fantasy|Horror|Thriller
# 9081                              Horror|Science Fiction
# 9286                       Comedy|Horror|Science Fiction
# 9421                                         Documentary
# 9539                                       Horror|Comedy
# 9586                                Drama|Family|Romance
# 9631                                     Family|TV Movie
# 9647              Action|Horror|Science Fiction|Thriller
# 9692         Animation|Science Fiction|Fantasy|Adventure
# 9708                                        Action|Crime
# 9763                              Comedy|Science Fiction
# 10012  Adventure|Animation|Comedy|Science Fiction|Family
# 10078                                   Drama|War|Action
# 10190                                       Action|Crime
# 10213                                  Documentary|Music
# 10238                            Animation|Comedy|Family
# 10328                                             Horror
# 10372                              Comedy|History|Horror
# 10567                                      Drama|History
# 10657                              Comedy|Drama|Thriller
# 10817                                  Documentary|Music
# 10819                                      Action|Comedy
#
#                                     production_companies release_date  \
# 30     BBC Films|See-Saw Films|FilmNation Entertainme...   2015-06-19
# 67     Nu Image Films|Winkler Films|Millennium Films|...   2015-05-21
# 75                                     Indian Paintbrush   2015-06-12
# 88     Scott Free Productions|Infinite Frameworks Stu...   2015-09-04
# 95     Regency Enterprises|Fox 2000 Pictures|Sunswept...   2015-12-17
# 132    Aardman Animations|Studio Canal|Anton Capital ...   2015-02-05
# 139    Palomar Pictures|Lucky Hat Entertainment|Silve...   2015-08-13
# 143                          Terra Mater Factual Studios   2015-12-24
# 148    Animus Films|Edward R. Pressman Film|Kreo Film...   2015-09-17
# 159                                       Laser Unicorns   2015-05-28
# 172    Studio Canal|See-Saw Films|Creative Scotland|F...   2015-08-16
# 173    Emmett/Furla Films|Oasis Films|Aperture Entert...   2015-12-18
# 174    MM Productions|Merced Media Partners|PalmStar ...   2015-07-31
# 181                               Warner Bros. Animation   2015-02-10
# 187                           Rhombus Media|Bron Studios   2015-06-03
# 195                  On The Corner Films|Universal Music   2015-07-03
# 197    Prescience|Bord Scannan na hEireann / Irish Fi...   2015-11-06
# 201                     Big Talk Productions|StudioCanal   2015-05-29
# 212                 Waypoint Entertainment|Dogwood Films   2015-09-10
# 214    Electric City Entertainment|Sycamore Pictures|...   2015-07-04
# 215                                 New Artists Alliance   2015-10-29
# 237       Original Pictures|Head Gear Films|Minnow Films   2015-03-13
# 239    Skyline Entertainment|Moetion Films|Ulysses Fi...   2015-04-09
# 241                            Two to Tangle Productions   2015-05-29
# 245                   FJ Productions|BB Film Productions   2015-10-16
# 255              Freestyle Releasing|ShadowMachine Films   2015-10-02
# 261    Myriad Pictures|Dreambridge Films|Bifrost Pict...   2015-01-09
# 269                        Lucasfilm|Touchstone Pictures   2015-01-23
# 272    The New Zealand Film Commission|Timpson Films|...   2015-08-28
# 285          Altitude Film Entertainment|AI-Film|Unigram   2015-11-06
# ...                                                  ...          ...
# 8465                    Walt Disney Television Animation   1996-05-20
# 8651                      Universal Pictures|Best Brains   1996-04-19
# 8733                Miramax Films|Industry Entertainment   2000-04-27
# 8768   New Amsterdam Entertainment|Tandem Communications   2000-12-03
# 8803   Unified Film Organization (UFO)|Python Product...   2000-08-09
# 8852                    Alcon Entertainment|Warner Bros.   2000-01-14
# 8870                     Columbia Pictures|Miramax Films   2000-12-11
# 8876   Filmtown Entertainment Group|El Dorado Picture...   2000-08-26
# 9039   Columbia Pictures|Largo Entertainment|JVC Ente...   1998-10-30
# 9081                          Starway International Inc.   1998-10-13
# 9286                                Wild Street Pictures   1989-10-01
# 9421              American Zoetrope|Cineplex-Odeon Films   1991-09-06
# 9539                                  Double Helix Films   1988-10-31
# 9586                                    TriStar Pictures   1988-01-15
# 9631                             Jim Henson Company, The   1987-12-16
# 9647   New Line Cinema|Heron Communications|Third Elm...   1987-10-30
# 9692                                            Films A2   1987-12-11
# 9708                                    Drafthouse Films   1987-08-18
# 9763   University of Southern California|Jack H. Harr...   1974-04-01
# 10012                                 Aardman Animations   1990-05-18
# 10078  Warner Bros.|Enigma Productions|Fujisankei Com...   1990-09-07
# 10190             Overseas FilmGroup|The CKK Corporation   1976-11-05
# 10213                             Warner Bros.|Swan Song   1976-11-05
# 10238                                 Aardman Animations   1993-12-17
# 10328                                  Showtime Networks   1993-08-07
# 10372  Avenging Conscience|Troma Entertainment|Cannib...   1993-10-01
# 10567                       British Film Institute (BFI)   1986-08-29
# 10657             Twentieth Century Fox Film Corporation   2070-07-17
# 10817                     FM Productions|Last Waltz Inc.   1978-05-01
# 10819                                       Warner Bros.   1978-07-28
#
#        vote_count  vote_average  release_year
# 30            425           6.4          2015
# 67            280           5.4          2015
# 75            569           7.7          2015
# 88            135           5.6          2015
# 95            278           5.7          2015
# 132           340           6.9          2015
# 139           181           5.5          2015
# 143            11           7.5          2015
# 148           104           7.1          2015
# 159           487           7.7          2015
# 172           269           6.4          2015
# 173            57           4.2          2015
# 174            92           5.2          2015
# 181            14           6.4          2015
# 187            57           5.1          2015
# 195           345           7.5          2015
# 197           122           4.9          2015
# 201           264           6.5          2015
# 212           101           5.7          2015
# 214            74           5.7          2015
# 215            98           4.2          2015
# 237           133           6.0          2015
# 239            50           5.7          2015
# 241           158           5.9          2015
# 245            94           6.9          2015
# 255            47           4.3          2015
# 261            13           5.8          2015
# 269            68           6.1          2015
# 272            83           6.5          2015
# 285            54           5.5          2015
# ...           ...           ...           ...
# 8465          308           6.2          1996
# 8651           41           7.0          1996
# 8733           41           5.8          2000
# 8768           67           6.5          2000
# 8803           10           3.5          2000
# 8852           30           6.1          2000
# 8870           27           5.5          2000
# 8876           19           5.7          2000
# 9039          109           5.8          1998
# 9081           15           4.6          1998
# 9286           24           5.8          1989
# 9421           28           7.8          1991
# 9539           20           6.0          1988
# 9586           12           6.4          1988
# 9631           11           6.5          1987
# 9647           26           6.4          1987
# 9692           10           7.2          1987
# 9708           13           5.8          1987
# 9763           43           5.4          1974
# 10012         103           7.3          1990
# 10078          65           6.0          1990
# 10190          80           7.0          1976
# 10213          14           7.0          1976
# 10238         146           7.4          1993
# 10328          21           5.3          1993
# 10372          19           6.7          1993
# 10567          13           4.7          1986
# 10657          19           6.2          1970
# 10817          33           8.0          1978
# 10819          13           6.0          1978
#
# [705 rows x 14 columns]

# %%
#dropping the rows with zero values
df.drop(min_ero.index, axis=0, inplace=True)

# %%
#lets check our statistics to confirm if the error has been corrected
df.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    1287.000000  1287.000000  1.287000e+03  1.287000e+03  1287.000000
# mean    52557.491064     1.786022  5.200349e+07  1.762444e+08   110.273504
# std     74450.077163     2.172137  5.514540e+07  2.538156e+08    18.811369
# min        11.000000     0.010335  1.000000e+00  4.300000e+01    63.000000
# 25%      5851.500000     0.664783  1.400000e+07  2.565097e+07    97.000000
# 50%     20178.000000     1.152354  3.200000e+07  8.208716e+07   107.000000
# 75%     62209.500000     2.125342  7.000000e+07  2.140694e+08   121.000000
# max    333348.000000    32.985763  4.250000e+08  2.781506e+09   201.000000
#
#         vote_count  vote_average  release_year
# count  1287.000000   1287.000000   1287.000000
# mean    947.266511      6.279487   2007.017094
# std    1255.476215      0.795955      8.060503
# min      10.000000      2.200000   1961.000000
# 25%     179.000000      5.800000   2005.000000
# 50%     439.000000      6.300000   2009.000000
# 75%    1173.000000      6.800000   2011.000000
# max    9767.000000      8.300000   2015.000000

# %% [markdown]
# From the bove statistics we can see that all 0 (zero) values of min has been cleaned.
#
# Having cleaned our dataset, let's view the basic information of our cleaned data and the shape

# %%
#Information of cleaned data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1287 entries, 0 to 10760
# Data columns (total 14 columns):
# id                      1287 non-null int64
# popularity              1287 non-null float64
# budget                  1287 non-null int64
# revenue                 1287 non-null int64
# original_title          1287 non-null object
# director                1287 non-null object
# overview                1287 non-null object
# runtime                 1287 non-null int64
# genres                  1287 non-null object
# production_companies    1287 non-null object
# release_date            1287 non-null datetime64[ns]
# vote_count              1287 non-null int64
# vote_average            1287 non-null float64
# release_year            1287 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(5)
# memory usage: 150.8+ KB

# %%
#checking the shape of the dataset
df.shape
# Out:
# (1287, 14)

# %% [markdown]
# We have 1287 rows and 14 columns remaining

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
#
#
# ### Research Question 1: What year did TMDb Movies made the highest profit?

# %% [markdown]
# To answer this question we need to create a new column for profit, This we would achieve by deducting our budget column data from revenue column data in the next step.

# %%
#creating a profit column
df['profit'] = df['revenue'] - df['budget']

# %%
#checking if our column has been created
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#            director                                           overview  \
# 0   Colin Trevorrow  Twenty-two years after the events of Jurassic ...
# 1     George Miller  An apocalyptic story set in the furthest reach...
# 2  Robert Schwentke  Beatrice Prior must confront her inner demons ...
# 3       J.J. Abrams  Thirty years after defeating the Galactic Empi...
# 4         James Wan  Deckard Shaw seeks revenge against Dominic Tor...
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# 1      120  Action|Adventure|Science Fiction|Thriller
# 2      119         Adventure|Science Fiction|Thriller
# 3      136   Action|Adventure|Science Fiction|Fantasy
# 4      137                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   2015-12-15        5292
# 4  Universal Pictures|Original Film|Media Rights ...   2015-04-01        2947
#
#    vote_average  release_year      profit
# 0           6.5          2015  1363528810
# 1           7.1          2015   228436354
# 2           6.3          2015   185238201
# 3           7.5          2015  1868178225
# 4           7.3          2015  1316249360

# %%
#checking the datatype of our profit column
df.profit.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# We can see that the new column is an integer. Let's proceed with our question

# %%
#assigning the first five years with the highest profit to maxp variable
maxp = df[['release_year','profit']].sort_values('profit', ascending = False).head(5) 

# we selected only release_year and profit column and sorted it descending order to get the first five years with the highest profit

# let's have a look at our new table 
maxp
# Out:
#       release_year      profit
# 1386          2009  2544505847
# 3             2015  1868178225
# 5231          1997  1645034188
# 0             2015  1363528810
# 4             2015  1316249360

# %% [markdown]
# ##### From the above we can see that 2015 appeared three times which makes our query wrong.
# > 1. To resolve and get the actual year with the highest profit, we need to get the unique year values with the sum of all the profit generated in each year from our table.
# > 2. After which we would create a new table with our result.
# > 3. We would plot our information in a barchart for proper visualization.

# %%
#grouping our data by release year and summing up the profit
year = df.groupby('release_year')['profit'].sum()

# %%
# let's have a look at our year dataset
year
# Out:
# release_year
# 1961        1000000
# 1962       58500000
# 1963       76398765
# 1964      121900549
# 1965      130195658
# 1967      102084787
# 1969       74974493
# 1971      170269000
# 1972      239066411
# 1973      588083981
# 1974       90572000
# 1975      579975267
# 1977      935836680
# 1978      208000000
# 1979      333891781
# 1980      540778361
# 1981      650164919
# 1982      790962062
# 1983      880612147
# 1984      648928023
# 1985      484537722
# 1986      -14000000
# 1987      385742146
# 1988       13291779
# 1989      872823860
# 1990      745978490
# 1991      336785279
# 1992     1016419063
# 1993     1272504993
# 1994      989416526
# 1995     1025681406
# 1996     1116678642
# 1997     2753205533
# 1998      815219235
# 1999     3851184237
# 2000     1307840750
# 2001     3148328186
# 2002     4156386568
# 2003     3996413806
# 2004     5859592722
# 2005     3761788467
# 2006     6088139016
# 2007    10014836079
# 2008     8017278395
# 2009    12722818634
# 2010    11995828331
# 2011    13960424906
# 2012    12942339736
# 2013    10927923265
# 2014    11578817708
# 2015    16531677567
# Name: profit, dtype: int64

# %% [markdown]
# Having achieved this we would sort our year data to get the first five years that has the highest profit

# %%
#sorting for the first five years with the highest profit
year.sort_values(ascending = False).head(5)
# Out:
# release_year
# 2015    16531677567
# 2011    13960424906
# 2012    12942339736
# 2009    12722818634
# 2010    11995828331
# Name: profit, dtype: int64

# %% [markdown]
# From our data we can see that TMDB movie made the highest profit in 2015
#
# We need to create a new table with our new dataset to plot it for proper visualization

# %%
# creating a new table with our new dataset 
year_p = pd.DataFrame({'year':[2015,2012,2011,2010,2009], 'profit':[16531677567,12942339736,13960424906,11995828331,12722818634]},columns=['year','profit'])

# %%
#lets have a look at our new table
year_p
# Out:
#    year       profit
# 0  2015  16531677567
# 1  2012  12942339736
# 2  2011  13960424906
# 3  2010  11995828331
# 4  2009  12722818634

# %%
#ploting our data on barchart for proper visualisation
plt.figure(figsize=(10,5))

#barchart
sns.barplot(x='year', y='profit', data=year_p)

# the title of our diagram
plt.title('The Top Five Years With the Highest Profit', fontsize=17)
#labelling x 
plt.xlabel('Year',fontsize=15)

#labelling y 
plt.ylabel('Profit',fontsize=15)

#Display
plt.show()

# %% [markdown]
# The barchart above shows that 2015 has the highest profit followed by 2011,2012,2009 and 2010

# %% [markdown]
# ### Research Question 2:  Which TMDb Movie has the Highest Profit  Expressed as a Percentage of its Budget?

# %% [markdown]
# For us to answer this question, we need to create a ne column called profit_by_budget. This profit_of_budget will be created by dividing our profit column data with the budget column and multiply it by 100 to get the percentage value.

# %%
#creating a new column called profit_of_budget
df['profit_by_budget'] = df['profit'] // df['budget'] * 100

# %%
#lets view the first two rows of our data to confirm if our new column was created 
df.head()
# Out:
#        id  popularity     budget     revenue                original_title  \
# 0  135397   32.985763  150000000  1513528810                Jurassic World
# 1   76341   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  262500   13.112507  110000000   295238201                     Insurgent
# 3  140607   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259    9.335014  190000000  1506249360                     Furious 7
#
#            director                                           overview  \
# 0   Colin Trevorrow  Twenty-two years after the events of Jurassic ...
# 1     George Miller  An apocalyptic story set in the furthest reach...
# 2  Robert Schwentke  Beatrice Prior must confront her inner demons ...
# 3       J.J. Abrams  Thirty years after defeating the Galactic Empi...
# 4         James Wan  Deckard Shaw seeks revenge against Dominic Tor...
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# 1      120  Action|Adventure|Science Fiction|Thriller
# 2      119         Adventure|Science Fiction|Thriller
# 3      136   Action|Adventure|Science Fiction|Fantasy
# 4      137                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...   2015-06-09        5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...   2015-05-13        6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...   2015-03-18        2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   2015-12-15        5292
# 4  Universal Pictures|Original Film|Media Rights ...   2015-04-01        2947
#
#    vote_average  release_year      profit  profit_by_budget
# 0           6.5          2015  1363528810               900
# 1           7.1          2015   228436354               100
# 2           6.3          2015   185238201               100
# 3           7.5          2015  1868178225               900
# 4           7.3          2015  1316249360               600

# %%
#lets see the data type of our new column
df.profit_by_budget.dtypes
# Out:
# dtype('int64')

# %%
#Let's have a look at the information of our new dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1287 entries, 0 to 10760
# Data columns (total 16 columns):
# id                      1287 non-null int64
# popularity              1287 non-null float64
# budget                  1287 non-null int64
# revenue                 1287 non-null int64
# original_title          1287 non-null object
# director                1287 non-null object
# overview                1287 non-null object
# runtime                 1287 non-null int64
# genres                  1287 non-null object
# production_companies    1287 non-null object
# release_date            1287 non-null datetime64[ns]
# vote_count              1287 non-null int64
# vote_average            1287 non-null float64
# release_year            1287 non-null int64
# profit                  1287 non-null int64
# profit_by_budget        1287 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(8), object(5)
# memory usage: 170.9+ KB

# %% [markdown]
#  ##### Our profit_of_budget is a float datatype but pandas stored it as integer. We would proceed to correct this error in the next step below.

# %%
# Convert the profit_of_budget to float
df.profit_by_budget = df.profit_by_budget.astype(float)

# %%
#Let's confirm if it has been converted to float
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1287 entries, 0 to 10760
# Data columns (total 16 columns):
# id                      1287 non-null int64
# popularity              1287 non-null float64
# budget                  1287 non-null int64
# revenue                 1287 non-null int64
# original_title          1287 non-null object
# director                1287 non-null object
# overview                1287 non-null object
# runtime                 1287 non-null int64
# genres                  1287 non-null object
# production_companies    1287 non-null object
# release_date            1287 non-null datetime64[ns]
# vote_count              1287 non-null int64
# vote_average            1287 non-null float64
# release_year            1287 non-null int64
# profit                  1287 non-null int64
# profit_by_budget        1287 non-null float64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 170.9+ KB

# %% [markdown]
# We can see that our profit_by_budget column data has been converted to float

# %%
#sorting our data to get the first five movie titles with the highest profit expressed as a percentage of there budget
movie_p = df[['original_title','profit_by_budget']].sort_values('profit_by_budget', ascending=False).head()
movie_p
# Out:
#                original_title  profit_by_budget
# 3608       From Prada to Nada         2688000.0
# 7447      Paranormal Activity         1288900.0
# 2449  The Blair Witch Project          991900.0
# 3581  Love, Wedding, Marriage          137700.0
# 242               The Gallows           42500.0

# %% [markdown]
# We can see that `From Prada to Nada` movie has the highest profit when expressed as a percentage of it's budget.
#
# Let's plot our information on a chart for proper visualization.

# %%
#reseting the index column to original title
movie_p.set_index('original_title', inplace=True)

# %%
#checking if our index column has changed to original title
movie_p
# Out:
#                          profit_by_budget
# original_title
# From Prada to Nada              2688000.0
# Paranormal Activity             1288900.0
# The Blair Witch Project          991900.0
# Love, Wedding, Marriage          137700.0
# The Gallows                       42500.0

# %%
#defining the size of our diagram
plt.figure(figsize=(3.5,3.5))

#size of our movie title text
textprops = {"fontsize":13}

#organizing our data in a piechart for proper visualisation
plt.pie(movie_p.profit_by_budget, labels=movie_p.index, textprops = textprops, labeldistance=1.05, autopct ='%.0f%%', shadow=True, frame=True)

#legend
plt.legend(labels=movie_p.index, loc='upper center', bbox_to_anchor=(1.7,1), ncol=1, fontsize=12)

#Title of our piechart
plt.title('The First Five Movies with the Highest Profit relative to the budget', loc='left', fontsize = 15)

#display
plt.show()

# %% [markdown]
# We can clearly see from the piechart above that `From Prada to Nada` has the highest profit related to budget followed by `paranormal Activity`
#
# `The Blair Witch Project`, `Love, Wedding, Marriage` and `The Gallows`

# %% [markdown]
# ### Research Question 3: What is the correlation between the attributes of our TMDb movies dataset?

# %%
#finding the correlation in our dataset
cor = df.corr()

# %%
#calling out our correlation
cor
# Out:
#                         id  popularity    budget   revenue   runtime  \
# id                1.000000    0.189301 -0.050921 -0.031441 -0.013123
# popularity        0.189301    1.000000  0.432791  0.594755  0.322390
# budget           -0.050921    0.432791  1.000000  0.706888  0.337373
# revenue          -0.031441    0.594755  0.706888  1.000000  0.371226
# runtime          -0.013123    0.322390  0.337373  0.371226  1.000000
# vote_count        0.059368    0.744088  0.583038  0.775374  0.426505
# vote_average      0.004985    0.355904  0.075168  0.296501  0.385210
# release_year      0.494397    0.059243  0.179160  0.028022 -0.071863
# profit           -0.023688    0.582064  0.569160  0.983914  0.346323
# profit_by_budget -0.010274   -0.021513 -0.045054 -0.012822 -0.034892
#
#                   vote_count  vote_average  release_year    profit  \
# id                  0.059368      0.004985      0.494397 -0.023688
# popularity          0.744088      0.355904      0.059243  0.582064
# budget              0.583038      0.075168      0.179160  0.569160
# revenue             0.775374      0.296501      0.028022  0.983914
# runtime             0.426505      0.385210     -0.071863  0.346323
# vote_count          1.000000      0.464812      0.071290  0.754078
# vote_average        0.464812      1.000000     -0.163737  0.325682
# release_year        0.071290     -0.163737      1.000000 -0.012674
# profit              0.754078      0.325682     -0.012674  1.000000
# profit_by_budget   -0.022417     -0.034183     -0.000087 -0.003527
#
#                   profit_by_budget
# id                       -0.010274
# popularity               -0.021513
# budget                   -0.045054
# revenue                  -0.012822
# runtime                  -0.034892
# vote_count               -0.022417
# vote_average             -0.034183
# release_year             -0.000087
# profit                   -0.003527
# profit_by_budget          1.000000

# %% [markdown]
# For proper visualisation and understanding of the above statistics, we would plot our correlation on a heat map chart.

# %%
#defining the size of our diagram
plt.figure(figsize=(15,7.5))

#plotting our correlation on Heat map chart
sns.heatmap(cor, cmap = 'coolwarm', annot =True)

# %% [markdown]
# From our statistics above we can see that;
# <Ul>
#     <li>`popularity` has a high correlation with `vote_count` of 0.74 which means that, the popularity of a movie is dependent on its vote count. Also the lower the vote count the lower the popularity of each movie and vice versa.</li><br>
#     <li>`revenue` has a high correlation with `budget`, meaning that the amount of revenue generated on any movie depends on the budget of the movie.</li><br>
#     <li>`revenue` also has a high correlation with `vote_counts` and `profit` with 0.98 for profit and 0.78 for vote counts. This implies that the higher the vote_counts the higher the popularity which leads to increase in revenue and as well increase the profit generated.</li><br>
#     <li>`vote_counts` has a high correlation with `profit`, which means that the higher the number of votes received from people on each movie results to that movie making more profit.</li>
# </Ul>

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions and Findings
#
# > 1. From our analysis we were able to ascertain that TMDb movies generated the highest profit in `2015`.
# > 2. Also, we discovered that `From Prada to Nada` movie has the highest profit in relative to budget.
# > 3. We found that;
# <Ul>
#        <li>`revenue` and `popularity` is highly correlated with `vote_counts`.</li>
#        <li>`revenue` is highly correlated with `budget`.</li>
#        <li>`vote_counts` is highly correlated with `profit`.</li>
# </Ul>
#
# ## Limitations
#
# > The filtered dataset contained vast number of Null values of which certain revenue values where dropped when budget is zero and budget when revenue is zero as well. Also, I dropped many columns from the dataset which where not needed for my analysis.
#
# > ## Refrences
# > [Stackoverflow](https://stackoverflow.com)<br>
# > [Matplotlib Pie Chart](https://pythonguides.com/matplotlib-pie-chart/)

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
# Out:
# 0
